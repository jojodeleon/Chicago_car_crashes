# %%
import pandas as pd

data = pd.read_csv('ChiTrafCrash')
people = pd.read_csv('ChiPeopCrash')

all_df = pd.merge(data, people, on='CRASH_RECORD_ID')
all_df.head()
# Out:
# /home/jojo/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (12,13,20,21,22,23,24,25,26,27,29) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                                      CRASH_RECORD_ID   RD_NO_x  \
# 0  4fd0a3e0897b3335b94cd8d5b2d2b350eb691add56c62d...  JC343143
# 1  4fd0a3e0897b3335b94cd8d5b2d2b350eb691add56c62d...  JC343143
# 2  4fd0a3e0897b3335b94cd8d5b2d2b350eb691add56c62d...  JC343143
# 3  009e9e67203442370272e1a13d6ee51a4155dac65e583d...  JA329216
# 4  009e9e67203442370272e1a13d6ee51a4155dac65e583d...  JA329216
#
#   CRASH_DATE_EST_I            CRASH_DATE_x  POSTED_SPEED_LIMIT  \
# 0              NaN  07/10/2019 05:56:00 PM                  35
# 1              NaN  07/10/2019 05:56:00 PM                  35
# 2              NaN  07/10/2019 05:56:00 PM                  35
# 3              NaN  06/30/2017 04:00:00 PM                  35
# 4              NaN  06/30/2017 04:00:00 PM                  35
#
#   TRAFFIC_CONTROL_DEVICE      DEVICE_CONDITION WEATHER_CONDITION  \
# 0            NO CONTROLS           NO CONTROLS             CLEAR
# 1            NO CONTROLS           NO CONTROLS             CLEAR
# 2            NO CONTROLS           NO CONTROLS             CLEAR
# 3      STOP SIGN/FLASHER  FUNCTIONING PROPERLY             CLEAR
# 4      STOP SIGN/FLASHER  FUNCTIONING PROPERLY             CLEAR
#
#   LIGHTING_CONDITION FIRST_CRASH_TYPE  ... EMS_RUN_NO     DRIVER_ACTION  \
# 0           DAYLIGHT          TURNING  ...        NaN  IMPROPER BACKING
# 1           DAYLIGHT          TURNING  ...        NaN              NONE
# 2           DAYLIGHT          TURNING  ...        NaN               NaN
# 3           DAYLIGHT          TURNING  ...        NaN   FAILED TO YIELD
# 4           DAYLIGHT          TURNING  ...        NaN              NONE
#
#   DRIVER_VISION PHYSICAL_CONDITION PEDPEDAL_ACTION PEDPEDAL_VISIBILITY  \
# 0       UNKNOWN             NORMAL             NaN                 NaN
# 1  NOT OBSCURED             NORMAL             NaN                 NaN
# 2           NaN                NaN             NaN                 NaN
# 3       UNKNOWN            UNKNOWN             NaN                 NaN
# 4  NOT OBSCURED             NORMAL             NaN                 NaN
#
#   PEDPEDAL_LOCATION        BAC_RESULT BAC_RESULT VALUE CELL_PHONE_USE
# 0               NaN  TEST NOT OFFERED              NaN            NaN
# 1               NaN  TEST NOT OFFERED              NaN            NaN
# 2               NaN               NaN              NaN            NaN
# 3               NaN  TEST NOT OFFERED              NaN            NaN
# 4               NaN  TEST NOT OFFERED              NaN            NaN
#
# [5 rows x 78 columns]

# %%
drop_cols = ['CRASH_RECORD_ID','RD_NO_x', 'CRASH_DATE_EST_I', 'BEAT_OF_OCCURRENCE', 'DATE_POLICE_NOTIFIED', 
             'REPORT_TYPE', 'DAMAGE', 'PHOTOS_TAKEN_I', 'STATEMENTS_TAKEN_I', 'MOST_SEVERE_INJURY', 
             'INJURIES_TOTAL', 'INJURIES_FATAL', 'INJURIES_INCAPACITATING', 'INJURIES_NON_INCAPACITATING', 
             'INJURIES_REPORTED_NOT_EVIDENT', 'INJURIES_NO_INDICATION', 'INJURIES_UNKNOWN', 'ALIGNMENT', 
             'DEVICE_CONDITION', 'STREET_NO', 'STREET_DIRECTION', 'WORK_ZONE_TYPE', 'WORKERS_PRESENT_I', 
             'LANE_CNT', 'PERSON_ID', 'VEHICLE_ID', 'CRASH_DATE_y', 'CITY', 'STATE', 'ZIPCODE', 'LATITUDE', 
             'LONGITUDE', 'RD_NO_y', 'DRIVERS_LICENSE_STATE', 'AIRBAG_DEPLOYED', 'EJECTION', 'HOSPITAL', 
             'EMS_AGENCY', 'EMS_RUN_NO', 'PEDPEDAL_ACTION', 'PEDPEDAL_VISIBILITY', 'PEDPEDAL_LOCATION', 
             'BAC_RESULT VALUE', 'CELL_PHONE_USE', 'CRASH_DATE_x', 'DOORING_I', 'NOT_RIGHT_OF_WAY_I', 
             'HIT_AND_RUN_I', 'SEC_CONTRIBUTORY_CAUSE', 'WORK_ZONE_I', 'SEAT_NO', 'FIRST_CRASH_TYPE', 
             'TRAFFICWAY_TYPE', 'CRASH_TYPE', 'NUM_UNITS', 'LOCATION', 'BAC_RESULT', 'DRIVER_ACTION', 
             'DRIVER_VISION']

all_df.drop(drop_cols, axis=1, inplace=True)
all_df
# Out:
#          POSTED_SPEED_LIMIT TRAFFIC_CONTROL_DEVICE WEATHER_CONDITION  \
# 0                        35            NO CONTROLS             CLEAR
# 1                        35            NO CONTROLS             CLEAR
# 2                        35            NO CONTROLS             CLEAR
# 3                        35      STOP SIGN/FLASHER             CLEAR
# 4                        35      STOP SIGN/FLASHER             CLEAR
# ...                     ...                    ...               ...
# 1168857                  30            NO CONTROLS             CLEAR
# 1168858                  30            NO CONTROLS             CLEAR
# 1168859                  15            NO CONTROLS             CLEAR
# 1168860                  30            NO CONTROLS             CLEAR
# 1168861                  30            NO CONTROLS             CLEAR
#
#         LIGHTING_CONDITION ROADWAY_SURFACE_COND ROAD_DEFECT  \
# 0                 DAYLIGHT                  DRY  NO DEFECTS
# 1                 DAYLIGHT                  DRY  NO DEFECTS
# 2                 DAYLIGHT                  DRY  NO DEFECTS
# 3                 DAYLIGHT                  DRY  NO DEFECTS
# 4                 DAYLIGHT                  DRY  NO DEFECTS
# ...                    ...                  ...         ...
# 1168857           DAYLIGHT                  DRY  NO DEFECTS
# 1168858           DAYLIGHT                  DRY  NO DEFECTS
# 1168859           DAYLIGHT                  DRY  NO DEFECTS
# 1168860           DAYLIGHT                  DRY  NO DEFECTS
# 1168861           DAYLIGHT                  DRY  NO DEFECTS
#
#         INTERSECTION_RELATED_I        PRIM_CONTRIBUTORY_CAUSE   STREET_NAME  \
# 0                          NaN               IMPROPER BACKING   MARMORA AVE
# 1                          NaN               IMPROPER BACKING   MARMORA AVE
# 2                          NaN               IMPROPER BACKING   MARMORA AVE
# 3                            Y  FAILING TO YIELD RIGHT-OF-WAY    CICERO AVE
# 4                            Y  FAILING TO YIELD RIGHT-OF-WAY    CICERO AVE
# ...                        ...                            ...           ...
# 1168857                      Y            UNABLE TO DETERMINE  MICHIGAN AVE
# 1168858                      Y            UNABLE TO DETERMINE  MICHIGAN AVE
# 1168859                    NaN            UNABLE TO DETERMINE       WOOD ST
# 1168860                    NaN            UNABLE TO DETERMINE     DEVON AVE
# 1168861                    NaN            UNABLE TO DETERMINE     DEVON AVE
#
#          CRASH_HOUR  CRASH_DAY_OF_WEEK  CRASH_MONTH PERSON_TYPE SEX   AGE  \
# 0                17                  4            7      DRIVER   M  31.0
# 1                17                  4            7      DRIVER   M  43.0
# 2                17                  4            7   PASSENGER   M  28.0
# 3                16                  6            6      DRIVER   F  20.0
# 4                16                  6            6      DRIVER   F  26.0
# ...             ...                ...          ...         ...  ..   ...
# 1168857          10                  2            7      DRIVER   M   NaN
# 1168858          10                  2            7      DRIVER   F  25.0
# 1168859          16                  3            7      DRIVER   X   NaN
# 1168860          11                  3            7      DRIVER   X   NaN
# 1168861          11                  3            7      DRIVER   F  48.0
#
#         DRIVERS_LICENSE_CLASS  SAFETY_EQUIPMENT    INJURY_CLASSIFICATION  \
# 0                           D     USAGE UNKNOWN  NO INDICATION OF INJURY
# 1                           D     USAGE UNKNOWN  NO INDICATION OF INJURY
# 2                         NaN     USAGE UNKNOWN  NO INDICATION OF INJURY
# 3                           D     USAGE UNKNOWN  NO INDICATION OF INJURY
# 4                           D  SAFETY BELT USED  NO INDICATION OF INJURY
# ...                       ...               ...                      ...
# 1168857                   NaN     USAGE UNKNOWN  NO INDICATION OF INJURY
# 1168858                     D  SAFETY BELT USED    REPORTED, NOT EVIDENT
# 1168859                   NaN     USAGE UNKNOWN  NO INDICATION OF INJURY
# 1168860                   NaN     USAGE UNKNOWN  NO INDICATION OF INJURY
# 1168861                     D  SAFETY BELT USED  NO INDICATION OF INJURY
#
#         PHYSICAL_CONDITION
# 0                   NORMAL
# 1                   NORMAL
# 2                      NaN
# 3                  UNKNOWN
# 4                   NORMAL
# ...                    ...
# 1168857            UNKNOWN
# 1168858             NORMAL
# 1168859            UNKNOWN
# 1168860            UNKNOWN
# 1168861             NORMAL
#
# [1168862 rows x 19 columns]

# %%
all_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1168862 entries, 0 to 1168861
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   POSTED_SPEED_LIMIT       1168862 non-null  int64
#  1   TRAFFIC_CONTROL_DEVICE   1168862 non-null  object
#  2   WEATHER_CONDITION        1168862 non-null  object
#  3   LIGHTING_CONDITION       1168862 non-null  object
#  4   ROADWAY_SURFACE_COND     1168862 non-null  object
#  5   ROAD_DEFECT              1168862 non-null  object
#  6   INTERSECTION_RELATED_I   318673 non-null   object
#  7   PRIM_CONTRIBUTORY_CAUSE  1168862 non-null  object
#  8   STREET_NAME              1168860 non-null  object
#  9   CRASH_HOUR               1168862 non-null  int64
#  10  CRASH_DAY_OF_WEEK        1168862 non-null  int64
#  11  CRASH_MONTH              1168862 non-null  int64
#  12  PERSON_TYPE              1168862 non-null  object
#  13  SEX                      1151267 non-null  object
#  14  AGE                      833902 non-null   float64
#  15  DRIVERS_LICENSE_CLASS    595860 non-null   object
#  16  SAFETY_EQUIPMENT         1165443 non-null  object
#  17  INJURY_CLASSIFICATION    1168275 non-null  object
#  18  PHYSICAL_CONDITION       928216 non-null   object
# dtypes: float64(1), int64(4), object(14)
# memory usage: 178.4+ MB

# %%
#drop rows where the accident is not from a car driver
all_df.drop(all_df.loc[all_df['PERSON_TYPE'] == 'PASSENGER'].index, inplace=True)
all_df.drop(all_df.loc[all_df['PERSON_TYPE'] == 'PEDESTRIAN'].index, inplace=True)
all_df.drop(all_df.loc[all_df['PERSON_TYPE'] == 'BICYCLE'].index, inplace=True)
all_df.drop(all_df.loc[all_df['PERSON_TYPE'] == 'NON-MOTOR VEHICLE'].index, inplace=True)
all_df.drop(all_df.loc[all_df['PERSON_TYPE'] == 'NON-CONTACT VEHICLE'].index, inplace=True)
all_df
# Out:
#          POSTED_SPEED_LIMIT TRAFFIC_CONTROL_DEVICE WEATHER_CONDITION  \
# 0                        35            NO CONTROLS             CLEAR
# 1                        35            NO CONTROLS             CLEAR
# 3                        35      STOP SIGN/FLASHER             CLEAR
# 4                        35      STOP SIGN/FLASHER             CLEAR
# 6                        30         TRAFFIC SIGNAL             CLEAR
# ...                     ...                    ...               ...
# 1168857                  30            NO CONTROLS             CLEAR
# 1168858                  30            NO CONTROLS             CLEAR
# 1168859                  15            NO CONTROLS             CLEAR
# 1168860                  30            NO CONTROLS             CLEAR
# 1168861                  30            NO CONTROLS             CLEAR
#
#         LIGHTING_CONDITION ROADWAY_SURFACE_COND ROAD_DEFECT  \
# 0                 DAYLIGHT                  DRY  NO DEFECTS
# 1                 DAYLIGHT                  DRY  NO DEFECTS
# 3                 DAYLIGHT                  DRY  NO DEFECTS
# 4                 DAYLIGHT                  DRY  NO DEFECTS
# 6                 DAYLIGHT                  DRY  NO DEFECTS
# ...                    ...                  ...         ...
# 1168857           DAYLIGHT                  DRY  NO DEFECTS
# 1168858           DAYLIGHT                  DRY  NO DEFECTS
# 1168859           DAYLIGHT                  DRY  NO DEFECTS
# 1168860           DAYLIGHT                  DRY  NO DEFECTS
# 1168861           DAYLIGHT                  DRY  NO DEFECTS
#
#         INTERSECTION_RELATED_I        PRIM_CONTRIBUTORY_CAUSE   STREET_NAME  \
# 0                          NaN               IMPROPER BACKING   MARMORA AVE
# 1                          NaN               IMPROPER BACKING   MARMORA AVE
# 3                            Y  FAILING TO YIELD RIGHT-OF-WAY    CICERO AVE
# 4                            Y  FAILING TO YIELD RIGHT-OF-WAY    CICERO AVE
# 6                          NaN  FAILING TO YIELD RIGHT-OF-WAY       67TH ST
# ...                        ...                            ...           ...
# 1168857                      Y            UNABLE TO DETERMINE  MICHIGAN AVE
# 1168858                      Y            UNABLE TO DETERMINE  MICHIGAN AVE
# 1168859                    NaN            UNABLE TO DETERMINE       WOOD ST
# 1168860                    NaN            UNABLE TO DETERMINE     DEVON AVE
# 1168861                    NaN            UNABLE TO DETERMINE     DEVON AVE
#
#          CRASH_HOUR  CRASH_DAY_OF_WEEK  CRASH_MONTH PERSON_TYPE SEX   AGE  \
# 0                17                  4            7      DRIVER   M  31.0
# 1                17                  4            7      DRIVER   M  43.0
# 3                16                  6            6      DRIVER   F  20.0
# 4                16                  6            6      DRIVER   F  26.0
# 6                10                  6            7      DRIVER   M  50.0
# ...             ...                ...          ...         ...  ..   ...
# 1168857          10                  2            7      DRIVER   M   NaN
# 1168858          10                  2            7      DRIVER   F  25.0
# 1168859          16                  3            7      DRIVER   X   NaN
# 1168860          11                  3            7      DRIVER   X   NaN
# 1168861          11                  3            7      DRIVER   F  48.0
#
#         DRIVERS_LICENSE_CLASS  SAFETY_EQUIPMENT    INJURY_CLASSIFICATION  \
# 0                           D     USAGE UNKNOWN  NO INDICATION OF INJURY
# 1                           D     USAGE UNKNOWN  NO INDICATION OF INJURY
# 3                           D     USAGE UNKNOWN  NO INDICATION OF INJURY
# 4                           D  SAFETY BELT USED  NO INDICATION OF INJURY
# 6                           D     USAGE UNKNOWN  NO INDICATION OF INJURY
# ...                       ...               ...                      ...
# 1168857                   NaN     USAGE UNKNOWN  NO INDICATION OF INJURY
# 1168858                     D  SAFETY BELT USED    REPORTED, NOT EVIDENT
# 1168859                   NaN     USAGE UNKNOWN  NO INDICATION OF INJURY
# 1168860                   NaN     USAGE UNKNOWN  NO INDICATION OF INJURY
# 1168861                     D  SAFETY BELT USED  NO INDICATION OF INJURY
#
#         PHYSICAL_CONDITION
# 0                   NORMAL
# 1                   NORMAL
# 3                  UNKNOWN
# 4                   NORMAL
# 6                   NORMAL
# ...                    ...
# 1168857            UNKNOWN
# 1168858             NORMAL
# 1168859            UNKNOWN
# 1168860            UNKNOWN
# 1168861             NORMAL
#
# [907222 rows x 19 columns]

# %%
all_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 907222 entries, 0 to 1168861
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   POSTED_SPEED_LIMIT       907222 non-null  object
#  1   TRAFFIC_CONTROL_DEVICE   907222 non-null  object
#  2   WEATHER_CONDITION        907222 non-null  object
#  3   LIGHTING_CONDITION       907222 non-null  object
#  4   ROADWAY_SURFACE_COND     907222 non-null  object
#  5   ROAD_DEFECT              907222 non-null  object
#  6   INTERSECTION_RELATED_I   233916 non-null  object
#  7   PRIM_CONTRIBUTORY_CAUSE  907222 non-null  object
#  8   STREET_NAME              907220 non-null  object
#  9   CRASH_HOUR               907222 non-null  object
#  10  CRASH_DAY_OF_WEEK        907222 non-null  int64
#  11  CRASH_MONTH              907222 non-null  int64
#  12  PERSON_TYPE              907222 non-null  object
#  13  SEX                      907125 non-null  object
#  14  AGE                      669308 non-null  float64
#  15  DRIVERS_LICENSE_CLASS    595803 non-null  object
#  16  SAFETY_EQUIPMENT         907222 non-null  object
#  17  INJURY_CLASSIFICATION    907222 non-null  object
#  18  PHYSICAL_CONDITION       907222 non-null  object
# dtypes: float64(1), int64(2), object(16)
# memory usage: 138.4+ MB

# %%
#FUNCTIONS TO CHANGE INDIVIDUAL COLUMNS
def speed_limit(rate):
    speed = float(rate)
    if speed < 10:
        return 'below_10'
    elif speed < 15:
        return '10'
    elif speed < 20:
        return '15'
    elif speed < 25:
        return '20'
    elif speed < 30:
        return '25'
    elif speed < 35:
        return '30'
    elif speed < 40:
        return '35'
    elif speed < 45:
        return '40'
    elif speed < 50:
        return '45'
    else:
        return 'above_45'
    
    
def traffic_device(device):
    keep = ['NO CONTROLS', 'TRAFFIC SIGNAL', 'STOP SIGN/FLASHER', 'UNKNOWN', 'OTHER']
    if device in keep:
        return device
    else:
        return 'OTHER'

    
def weather(condition):
    keep = ['CLEAR', 'RAIN', 'SNOW', 'UNKNOWN', 'OTHER']
    if condition in keep:
        return condition
    else:
        return 'OTHER'


def defects(defect):
    keep = ['NO DEFECTS', 'UNKNOWN', 'OTHER']
    if defect in keep:
        return defect
    else:
        return 'OTHER'

    
def time(hour):
    peak = [6,7,8,9,10,14,15,16,17,18,19]
    if hour in peak:
        return 'RUSH HRS'
    else:
        return 'NON RUSH HRS'

    
def license(type):
    if 'D' in type:
        return 'REGULAR'
    else:
        return 'SPECIAL'

    
def age_range(age):
    if age <= 15:
        return 'TOO YOUNG'
    if age < 20:
        return 'TEENAGER'
    elif age < 30:
        return 'TWENTIES'
    elif age < 40:
        return 'THIRTIES'
    elif age < 50:
        return 'FORTIES'
    elif age < 60:
        return 'FIFTIES'
    elif age < 70:
        return 'SIXTIES'
    elif age < 80:
        return 'SEVENTIES'
    else:
        return 'EIGHTY OR OLDER'

    
def safety(equipment):
    keep = ['USAGE UNKNOWN', 'NONE PRESENT']
    used = ['SAFETY BELT USED', 'CHILD RESTRAINT USED', 'CHILD RESTRAINT - FORWARD FACING', 
            'BICYCLE HELMET (PEDACYCLIST INVOLVED ONLY)', 'HELMET USED', 'DOT COMPLIANT MOTORCYCLE HELMET', 
            'CHILD RESTRAINT - TYPE UNKNOWN', 'CHILD RESTRAINT - REAR FACING', 'BOOSTER SEAT']
    if equipment in keep:
        return equipment
    elif equipment in used:
        return 'SAFETY USED'
    elif 'IMPROPERLY' in equipment:
        return 'USED IMPROPERLY'
    elif 'NOT USED' in equipment:
        return 'NOT USED'
    elif 'NOT DOT' in equipment:
        return 'USED IMPROPERLY'
    else:
        return 'OTHER' 

    
def road_surface(condition):
    keep = ['WET', 'DRY', 'OTHER', 'UNKNOWN']
    wet = ['SNOW OR SLUSH', 'ICE']
    if condition in keep:
        return condition
    elif condition in wet:
        return 'WET'
    else:
        return 'OTHER'

    
names = list(all_df.STREET_NAME.value_counts().sort_values()[1518:].index)
def street_acc(name):
    if name in names:
        return 'HIGH ACCIDENT RATE'
    else:
        return 'LOW ACCIDENT RATE'


def phys_cond(condition):
    keep = ['NORMAL', 'UNKNOWN', 'OTHER']
    substance = ['HAD BEEN DRINKING', 'MEDICATED']
    physical = ['FATIGUED/ASLEEP', 'EMOTIONAL', 'ILLNESS/FAINTED']
    if condition in keep:
        return condition
    elif 'IMPAIRED' in condition:
        return 'IMPAIRED'
    elif condition in substance:
        return 'IMPAIRED'
    elif condition in physical:
        return 'FATIGUE/ILL/EMOTION'
    else:
        return 'OTHER'

def primary(cause):
    keep = ['UNABLE TO DETERMINE', 'NOT APPLICABLE', 'WEATHER']
    construction = ['ROAD CONSTRUCTION/MAINTENANCE', 'ROAD ENGINEERING/SURFACE/MARKING DEFECTS']
    not_driver = ['VISION OBSCURED (SIGNS, TREE LIMBS, BUILDINGS, ETC.)', 
                  'EVASIVE ACTION DUE TO ANIMAL, OBJECT, NONMOTORIST', 'ANIMAL', 'OBSTRUCTED CROSSWALKS']
    if cause in keep:
        return cause
    elif cause in construction:
        return 'CONSTRUCTION'
    elif cause in not_driver:
        return 'NOT DRIVER FAULT'
    else:
        return 'DRIVER FAULT'

# %%
#apply functions to appropriate columns
#all_df.POSTED_SPEED_LIMIT = all_df.POSTED_SPEED_LIMIT.apply(speed_limit)
all_df.TRAFFIC_CONTROL_DEVICE = all_df.TRAFFIC_CONTROL_DEVICE.apply(traffic_device)
all_df.WEATHER_CONDITION = all_df.WEATHER_CONDITION.apply(weather)
all_df.ROAD_DEFECT = all_df.ROAD_DEFECT.apply(defects)
all_df.CRASH_HOUR = all_df.CRASH_HOUR.apply(time)
#all_df.DRIVERS_LICENSE_CLASS = all_df.DRIVERS_LICENSE_CLASS.apply(license)
all_df.AGE = all_df.AGE.apply(age_range)
all_df.SAFETY_EQUIPMENT = all_df.SAFETY_EQUIPMENT.apply(safety)
all_df.ROADWAY_SURFACE_COND = all_df.ROADWAY_SURFACE_COND.apply(road_surface)
all_df.PHYSICAL_CONDITION = all_df.PHYSICAL_CONDITION.apply(phys_cond)
all_df.PRIM_CONTRIBUTORY_CAUSE = all_df.PRIM_CONTRIBUTORY_CAUSE.apply(primary)


names = list(all_df.STREET_NAME.value_counts().sort_values()[1518:].index)
all_df.STREET_NAME = all_df.STREET_NAME.apply(street_acc)
